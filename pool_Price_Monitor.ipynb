# %% [markdown]
# # note
# this dumps to a differnet json

# %%
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
import pandas as pd
from selenium.webdriver.common.keys import Keys
import numpy as np
import time
from datetime import datetime
import json

# %%
prices = pd.DataFrame(columns=['scrape_time', 'amazon_name', 'amazon_price', 'target_name','target_price', 'walmart_name', 'walmart_price'])
path = '/Users/williamegan/Desktop/SPRING2020/3001/project/chromedriver'
with open('baskets/basket_list.json') as l:
    basket_list = json.load(l)
with open('baskets/allusers.json') as f:
    ASIN_dict = json.load(f)  


def scraper(url_list, path):
    global prices
  
    #loop through entries in list of URLs
    for amazon_url in url_list:
        # empty dictionary to store output
        row_results = {}

        #find product on amazon
        amazon_driver = Chrome(executable_path=path)
        amazon_driver.get(amazon_url)
        #wait for the webpage to load
        time.sleep(5)

        #grab product name from amazon
        row_results['amazon_name'] = amazon_driver.find_element_by_xpath('//*[@id="productTitle"]').text
        
        #get amazon price, if price is no longer available append 'Price not found'
        try:
            row_results['amazon_price'] = amazon_driver.find_element_by_xpath('//*[@id="priceblock_ourprice"]').text
        except:
            row_results['amazon_price'] = 'Price not found'
        
        #get the ASIN
        if len(amazon_url.split('/')) == 5:
            asin = amazon_url.split('/')[4]
        else:
            asin = amazon_url.split('/')[5]
        amazon_driver.quit()
                
        #if UPC for a specific asin has already been looked up do not look up
        if asin in ASIN_dict:
            upc_id = ASIN_dict[asin]
        
        
        #getting UPC from ASIN
        else:
            upc_driver = Chrome(executable_path=path)
            upc_driver.get('https://www.synccentric.com/features/upc-asin/')
            box = upc_driver.find_element_by_id('scrollto')
            form = box.find_element_by_class_name('form-group')
            input = form.find_element_by_name('identifier')
            input.send_keys(asin)
            input.submit()
            #wait for the webpage to load
            time.sleep(10)
            id_list = upc_driver.find_element_by_class_name('col-sm-8').find_elements_by_tag_name('strong')
            upc_id = id_list[1].get_attribute('innerHTML')
            upc_driver.quit()
            
            #add the new asin --> upc to the dict
            ASIN_dict[asin] = upc_id
            
            #sleep so you are not locked out
            if len(basket_list) >10:
                time.sleep(10)




        #find product on target
        target_driver = Chrome(executable_path=path)
        target_url = 'https://www.target.com/s?searchTerm=' + upc_id
        target_driver.get(target_url)
        #wait for the webpage to load
        time.sleep(5)
        
        #get target name if the item is found on target 
        try:
            target_name = target_driver.find_element_by_xpath('//*[@id="mainContainer"]/div[3]/div[2]/div/div[1]/div[3]/div/ul/li/div/div[2]/div/div/div/div[1]/div[1]/a').text
            row_results['target_name'] = target_name
        except:
            row_results['target_name'] = "Item not found"
        
        #get target price if item was found on target
        try:
            target_price = target_driver.find_element_by_xpath('//*[@id="mainContainer"]/div[3]/div[2]/div/div[1]/div[3]/div/ul/li/div/div[2]/div/div/div/div[2]/span').text
            row_results['target_price'] = target_price
        except:
            row_results['target_price'] = "Price not found"
 
        target_driver.quit()
    


        #find product on walmart
        walmart_driver = Chrome(executable_path=path)
        walmart_url = 'https://www.walmart.com/search/?query=' + upc_id
        walmart_driver.get(walmart_url)
        
        names_prices = walmart_driver.find_elements_by_xpath("//div[contains(@class, 'tile-content Grid-col u-size-8-10-l list-description-wrapper')]")
        
        #get walmart name and price if product was found on walmart
        if len(names_prices) == 0:
            
            row_results['walmart_name'] = 'Item not found'
            row_results['walmart_price'] = 'Price not found'
        else:
            for i in names_prices:
                if 'Pack' not in i.text:
                    #if name of the product from walmart has already been looked up do not scrape again
                    
                    price_list = i.text.split('\n')
                    row_results['walmart_name'] = price_list[price_list.index('Product Title')+1]
                    row_results['walmart_price'] = price_list[price_list.index('Current Price')+1]
                    
        walmart_driver.quit()

        
        #save results at time of scrape        
        timeofscrape = {}
        timeofscrape['scraped_at'] = str(datetime.today())
        timeofscrape['item'] = row_results
        with open('pool_test_price_monitor.json', 'a') as pm:
            json.dump(timeofscrape, pm)
            
        prices = prices.append(row_results, ignore_index=True)

# %% [markdown]
# # Base Run

# %%
st = time.time()
scraper(basket_list, path)
print('Took: ', time.time()-st)
# Out:
# Took:  1347.1229481697083

# %%
prices
# Out:
#    scrape_time                                        amazon_name  \
# 0          NaN  AOC C24G1 24" Curved Frameless Gaming Monitor,...
# 1          NaN  Skytech Shiva Gaming PC Desktop - AMD Ryzen 5 ...
# 2          NaN  OPTIMUM NUTRITION GOLD STANDARD 100% Whey Prot...
# 3          NaN  Whatafit Resistance Bands Set, Exercise Bands ...
# 4          NaN  TOPLUS Yoga Mat - Classic 1/4 inch Pro Yoga Ma...
# 5          NaN  Powerbeats Pro Wireless Earphones - Apple H1 H...
# 6          NaN  Sony X800H 65 Inch TV: 4K Ultra HD Smart LED T...
# 7          NaN  Bose Solo 5 TV Soundbar Sound System with Univ...
# 8          NaN  LEGO Harry Potter Hogwarts Clock Tower 75948 B...
# 9          NaN  L.O.L. Surprise! O.M.G. Miss Independent Fashi...
# 10         NaN  Contigo AUTOSEAL West Loop Vacuum-Insulated St...
# 11         NaN                   Apple AirPods with Charging Case
# 12         NaN  New Apple iPad Pro (12.9-inch, Wi-Fi, 256GB) -...
# 13         NaN  Bose SoundLink Revolve+ Portable and Long-Last...
# 14         NaN  Bose Noise Cancelling Wireless Bluetooth Headp...
# 15         NaN  KitchenAid KSM75SL Classic Plus 4.5-Qt. Tilt-H...
# 16         NaN  Keurig K-Elite Coffee Maker, Single Serve K-Cu...
# 17         NaN  Hamilton Beach Premium Juicer Machine, Big Mou...
# 18         NaN  Anova Culinary AN500-US00 Sous Vide Precision ...
# 19         NaN  Instant Pot Smart WiFi 8-in-1 Electric Pressur...
# 20         NaN  Fitbit Inspire HR Heart Rate and Fitness Track...
# 21         NaN  Vitamix E310 Explorian Blender, Professional-G...
# 22         NaN  Instant Vortex Plus 7-in-1 Air Fryer, Toaster ...
# 23         NaN  Babolat 2019 Boost Strike Tennis Racquet - STR...
# 24         NaN  XQXA Hat Washers, 2-Pack Hat Cleaners Baseball...
# 25         NaN  Nintendo Switch with Neon Blue and Neon Red Jo...
# 26         NaN  Nite Ize Flashflight LED Light Up Flying Disc,...
# 27         NaN  Bose QuietComfort 35 II Wireless Bluetooth Hea...
# 28         NaN  KitchenAid KSM75SL Classic Plus 4.5-Qt. Tilt-H...
# 29         NaN  Revlon One-Step Hair Dryer And Volumizer Hot A...
# 30         NaN                                GoPro Hero 7 Silver
# 31         NaN  D5600 DX-Format Digital SLR w/AF-P DX NIKKOR 1...
# 32         NaN  Fjallraven - Kanken Mini Classic Backpack for ...
# 33         NaN  Philips Computer Monitors 328E9QJAB 32" Curved...
# 34         NaN  Chefman 1.7 Liter Electric Glass Tea Kettle wi...
# 35         NaN  Instant Vortex 4-in-1 Air Fryer, 6 Quart, 4 On...
# 36         NaN  CeraVe Foaming Facial Cleanser | 16 Fl Oz | Da...
# 37         NaN  Lodge Cast Iron Skillet with Handle Holder, 12 In
# 38         NaN  KitchenAid KHB1231IC 2-Speed Hand Blender, Ice...
# 39         NaN  Lodge 5 Quart Cast Iron Dutch Oven. Pre-Season...
# 40         NaN  J.A. Henckels International Forged Premio 8-In...
# 41         NaN  George Foreman 8-Serving Classic Plate Grill a...
# 42         NaN  Cuisinart SS-15P1 Coffee Center 12-Cup Coffeem...
# 43         NaN  Cuisinart GR-4NP1 GR-4N 5-in-1 Griddler, 13.5"...
# 44         NaN  Cuisinart FP-8GMP1 Elemental 8-Cup Food Proces...
# 45         NaN  Weber 44010001 Spirit II E-210 2-Burner Liquid...
# 46         NaN  Weber 441001 Grilling, 35" H x 23" W x 18.5" L...
# 47         NaN              Dark Souls Remastered - PlayStation 4
# 48         NaN                   Dark Souls Remastered - Xbox One
# 49         NaN                    Bloodborne Hits - PlayStation 4
# 50         NaN                        Red Dead Redemption 2 (PS4)
# 51         NaN                   Red Dead Redemption 2 (XBox One)
# 52         NaN           Sekiro Shadows Die Twice - PlayStation 4
# 53         NaN                Sekiro Shadows Die Twice (Xbox One)
# 54         NaN                                  Halo 5 (Xbox One)
# 55         NaN                    God of War Hits - PlayStation 4
# 56         NaN                     Uncharted 4: A Thief's End PS4
#
#        amazon_price                                        target_name  \
# 0   Price not found                                     Item not found
# 1         $1,094.00                                     Item not found
# 2            $49.49                                     Item not found
# 3   Price not found                                     Item not found
# 4            $40.99                                     Item not found
# 5           $249.95      Powerbeats Pro True Wireless In-Ear Earphones
# 6           $898.00                                     Item not found
# 7           $179.00                               Bose Solo 5 Soundbar
# 8            $89.95                                     Item not found
# 9            $26.88                                     Item not found
# 10           $14.39                                     Item not found
# 11          $139.00             Apple AirPods with Wired Charging Case
# 12        $1,051.92   Apple iPad Pro 12.9-inch Wi-Fi Only (2020 Model)
# 13          $299.00     Bose® SoundLink Revolve Plus Bluetooth Speaker
# 14          $349.00      Bose Noise Cancelling Over-Ear Headphones 700
# 15          $219.99               KitchenAid Classic 4.5qt Stand Mixer
# 16          $169.99                                     Item not found
# 17           $99.00                                     Item not found
# 18          $199.00              Anova Sous Vide Wifi Precision Cooker
# 19          $147.09  Instant Pot Smart Wifi 6qt Multi-Use Electric ...
# 20           $99.95  Fitbit Inspire HR Activity Tracker with Small ...
# 21          $289.95              Vitamix Explorian E310 Blender 064068
# 22          $119.00        Instant Pot 10qt Vortex Plus Air Fryer Oven
# 23          $109.00                                     Item not found
# 24  Price not found                                     Item not found
# 25  Price not found  Nintendo Switch with Neon Blue and Neon Red Jo...
# 26           $18.26                                     Item not found
# 27          $244.94        Bose QuietComfort 35 Wireless Headphones II
# 28          $219.99               KitchenAid Classic 4.5qt Stand Mixer
# 29           $56.99     Revlon Salon One-Step Hair Dryer and Volumizer
# 30          $170.00                                 GoPro HERO7 Silver
# 31  Price not found  Nikon D5600 Digital SLR Camera 18-55mm - Black...
# 32  Price not found                                     Item not found
# 33          $199.99                                     Item not found
# 34  Price not found         Chefman 1.7L Glass Electric Kettle - Clear
# 35           $99.99                                     Item not found
# 36           $14.13  CeraVe Foaming Facial Cleanser for Normal to O...
# 37           $37.82                                     Item not found
# 38  Price not found  KitchenAid 2-Speed Immersion Hand Blender- KHB...
# 39           $39.90                                     Item not found
# 40           $34.95  J.A. Henckels 8" International Forged Premio C...
# 41           $62.95                                     Item not found
# 42          $179.86                                     Item not found
# 43           $71.99                                     Item not found
# 44           $75.79                                     Item not found
# 45          $379.00  Weber Spirit II E-210 44010001 2-Burner LP Gas...
# 46           $89.00  Weber 18" Original Kettle Charcoal Grill 44100...
# 47           $19.93                                     Item not found
# 48           $19.93                                     Item not found
# 49           $18.48      Bloodborne - PlayStation 4 (PlayStation Hits)
# 50           $42.13                                     Item not found
# 51           $45.95                                     Item not found
# 52  Price not found          Sekiro: Shadows Die Twice - PlayStation 4
# 53  Price not found                                     Item not found
# 54           $22.99                                     Item not found
# 55           $14.99      God of War - PlayStation 4 (PlayStation Hits)
# 56           $15.34                                     Item not found
#
#                          target_price  \
# 0                     Price not found
# 1                     Price not found
# 2                     Price not found
# 3                     Price not found
# 4                     Price not found
# 5                             $249.99
# 6                     Price not found
# 7                             $179.00
# 8                     Price not found
# 9                     Price not found
# 10                    Price not found
# 11                            $139.99
# 12                $999.99 - $1,299.99
# 13                            $299.99
# 14                            $349.99
# 15                            $259.99
# 16                    Price not found
# 17                    Price not found
# 18                            $199.99
# 19                            $149.99
# 20                             $99.95
# 21                            $349.99
# 22                            $119.99
# 23                    Price not found
# 24                    Price not found
# 25                            $299.99
# 26                    Price not found
# 27                  $299.99 - $349.99
# 28                            $259.99
# 29                    $56.99 - $59.99
# 30                            $199.99
# 31                            $649.99
# 32                    Price not found
# 33                    Price not found
# 34                             $19.99
# 35                    Price not found
# 36                             $14.99
# 37                    Price not found
# 38  See low price in cartWhat's this?
# 39                    Price not found
# 40                             $39.99
# 41                    Price not found
# 42                    Price not found
# 43                    Price not found
# 44                    Price not found
# 45                            $379.00
# 46                             $89.00
# 47                    Price not found
# 48                    Price not found
# 49                             $16.99
# 50                    Price not found
# 51                    Price not found
# 52                             $37.49
# 53                    Price not found
# 54                    Price not found
# 55                             $14.99
# 56                    Price not found
#
#                                          walmart_name    walmart_price
# 0                    AOC C24G1 Widescreen LCD Monitor          $336.47
# 1                                      Item not found  Price not found
# 2                                      Item not found  Price not found
# 3                                      Item not found  Price not found
# 4                                      Item not found  Price not found
# 5   Powerbeats Pro Totally Wireless Earphones with...          $244.99
# 6   Sony 65" Class 4K UHD LED Android Smart TV HDR...          $898.00
# 7            Bose Solo 5 TV Bluetooth Soundbar System          $179.00
# 8                                      Item not found  Price not found
# 9   L.O.L. Surprise! O.M.G. Miss Independent Fashi...           $26.88
# 10  CNO WLD100J01 16 oz West Loop Auto Seal Travel...           $20.82
# 11    Apple AirPods with Charging Case (Latest Model)          $139.00
# 12                                     Item not found  Price not found
# 13  Bose SoundLink Revolve + Portable Bluetooth Sp...          $299.00
# 14  Bose Noise Cancelling Wireless Headphones 700 ...          $349.00
# 15  KitchenAid Classic Plus? Series 4.5 Quart Tilt...          $259.99
# 16                                     Item not found  Price not found
# 17  Hamilton Beach Premium Big Mouth 2 Speed Juice...           $99.00
# 18              Anova Sous Vide Precision Cooker Wifi          $199.00
# 19                                     Item not found  Price not found
# 20  Fitbit Inspire HR, Fitness Tracker with Heart ...           $99.95
# 21                                     Item not found  Price not found
# 22  Instant Vortex Plus 10QT 7-in-1 Digital Air Fr...          $119.00
# 23                                     Item not found  Price not found
# 24                                     Item not found  Price not found
# 25                                     Item not found  Price not found
# 26  Nite Ize Flashflight LED Light Up Flying Disc,...           $32.99
# 27                                     Item not found  Price not found
# 28  KitchenAid Classic Plus? Series 4.5 Quart Tilt...          $259.99
# 29  Revlon One-Step Hair Dryer & Volumizer Hot Air...           $56.99
# 30              GoPro HERO7 Silver 4K30 Action Camera          $194.95
# 31   Nikon D5600 DSLR 24.2MP Camera with 18-55mm Lens          $518.00
# 32                                     Item not found  Price not found
# 33  Philips E-line 328E9QJAB 31.5" Full HD WLED LC...          $319.07
# 34  Chefman 1.7 Liter Electric Glass Tea Kettle wi...           $32.99
# 35              Instant Vortex 6 Quart 4in1 Air Fryer           $94.00
# 36  Cerave Oil Control Value Size Foaming Facial C...           $15.75
# 37                                     Item not found  Price not found
# 38                                     Item not found  Price not found
# 39  Lodge 5 Quart Cast Iron Dutch Oven. Pre-Season...           $37.67
# 40  J.A. Henckels International Forged Premio 8" C...           $34.51
# 41  George Foreman GR2121P 8-Serving Classic Plate...           $88.51
# 42  Cuisinart Coffee Makers Coffee Center? 12 Cup ...          $199.00
# 43             Cuisinart GR-4N 5-in-1 Griddler Silver          $100.41
# 44                                     Item not found  Price not found
# 45                                     Item not found  Price not found
# 46     Weber Original Kettle 18" Black Charcoal Grill          $111.06
# 47  Dark Souls: Remastered, Bandai/Namco, PlayStat...           $19.93
# 48  Dark Souls: Remastered, Bandai/Namco, Xbox One...           $19.93
# 49  Bloodborne - PlayStation Hits, Sony, PlayStati...           $18.48
# 50                                     Item not found  Price not found
# 51                                     Item not found  Price not found
# 52  Sekiro: Shadows Die Twice, Activision, PlaySta...           $43.00
# 53                                     Item not found  Price not found
# 54                                  halo 5 (xbox one)           $22.49
# 55  God of War ? PlayStation Hits, Sony, PlayStati...           $14.99
# 56                                     Item not found  Price not found

# %% [markdown]
# # Pooling Version

# %%
from multiprocessing.pool import Pool
from functools import partial

# %%
'''
Due to the particulars of pooling, we need to create a partial version of scraper that already has the path
defined
'''
scraper_partial = partial(scraper, path=path)

# %%
'''
we utilize a generator to split the input list into 4 lists
so that we can run reach on one of our 4 CPUs
'''
def chunkify(lst, n):
    """builds generator for dividing input lst into n chunks"""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]
chunked_basket = list(chunkify(basket_list, 4))

# %%
'''
we test the time it takes for us to use our 4 CPUs on the partial function and list of lists we have prepared
'''
st = time.time()

with Pool(4) as p:
    p.map(scraper_partial, chunked_basket)
    
print('Took: ', time.time()-st)
# Out:
# Took:  625.7137868404388

# %%
'''
we see a marked improvement! we have more than cut the time in half as compared to the base run
'''
625/1347
# Out:
# 0.4639940608760208

# %% [markdown]
# ### Note that the pooling run does not populate the prices dataframe

# %%
prices
# Out:
# Empty DataFrame
# Columns: [scrape_time, amazon_name, amazon_price, target_name, target_price, walmart_name, walmart_price]
# Index: []
